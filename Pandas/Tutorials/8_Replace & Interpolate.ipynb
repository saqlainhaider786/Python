# %%
import pandas as pd

# %%
val=pd.read_csv("D:\\Python\\Data Sets\\Financial Allocations.csv")
val=val.head(12)
val
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          0                          0.728552
# 1     Austria          1                          0.191309
# 2     Belgium          1                          0.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          0                               NaN
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          0.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          0.000000
# 9     Estonia          1                         29.656888
# 10    Finland          1                          0.856477
# 11     France          1                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %% [markdown]
# # Replace
# ***

# %%
# val.replace(to_replace=0,value=2)#replace(to_replace=value/data going to be place, value=new_value)

# %%
#same as
val.replace(0,2)
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          2                          0.728552
# 1     Austria          1                          0.191309
# 2     Belgium          1                          2.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          2                          2.000000
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          2.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          2.000000
# 9     Estonia          1                         29.656888
# 10    Finland          1                          0.856477
# 11     France          1                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %%
val.replace(to_replace=[0,1],value=[2,5])
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          2                          0.728552
# 1     Austria          5                          0.191309
# 2     Belgium          5                          2.000000
# 3    Bulgaria          5                          3.695839
# 4      Canada          2                          2.000000
# 5     Croatia          5                          0.001071
# 6      Cyprus          5                          2.000000
# 7         NaN          5                          0.131348
# 8     Denmark          5                          2.000000
# 9     Estonia          5                         29.656888
# 10    Finland          5                          0.856477
# 11     France          5                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %%
val.replace("Austria","Pakistan")
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          0                          0.728552
# 1    Pakistan          1                          0.191309
# 2     Belgium          1                          0.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          0                          0.000000
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          0.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          0.000000
# 9     Estonia          1                         29.656888
# 10    Finland          1                          0.856477
# 11     France          1                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %%
val.replace({"Country":"France"},"Pakistan")
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          0                          0.728552
# 1     Austria          1                          0.191309
# 2     Belgium          1                          0.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          0                          0.000000
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          0.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          0.000000
# 9     Estonia          1                         29.656888
# 10    Finland          1                          0.856477
# 11   Pakistan          1                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %% [markdown]
# ***
# # interpolate
# **Used to fill blank cells with randomly generated numbers.(It only works with numbers)**
# ***

# %%
val
# Out:
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          0                          0.728552
# 1     Austria          1                          0.191309
# 2     Belgium          1                          0.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          0                               NaN
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          0.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          0.000000
# 9     Estonia          1                         29.656888
# 10    Finland          1                          0.856477
# 11     France          1                          1.507460
#
#     Humanitarian allocations($ billion)  Military allocations($ billion)  \
# 0                              0.069499                         0.003587
# ...

# %%
val.interpolate(axis=0)
# Out:
# C:\Users\toshiba\AppData\Local\Temp\ipykernel_5072\3494746694.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   val.interpolate(axis=0)
#       Country  EU member  Financial allocations($ billion)  \
# 0   Australia          0                          0.728552
# 1     Austria          1                          0.191309
# 2     Belgium          1                          0.000000
# 3    Bulgaria          1                          3.695839
# 4      Canada          0                          1.848455
# 5     Croatia          1                          0.001071
# 6      Cyprus          1                          0.000000
# 7         NaN          1                          0.131348
# 8     Denmark          1                          0.000000
# 9     Estonia          1                         29.656888
# ...
